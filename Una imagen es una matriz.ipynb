# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use('classic')
imagen = Image.open('.\\imagenes\\cat.jpg')
plt.imshow(imagen)

# %%
imagen_gr = imagen.convert('LA')
print(imagen_gr)
imagen_gr
# Out:
# <PIL.Image.Image image mode=LA size=2121x1414 at 0x12DB4447580>
# <PIL.Image.Image image mode=LA size=2121x1414 at 0x12DB4447580>

# %%
imagen_mat = np.array(list(imagen_gr.getdata(band=0)), float)
imagen_mat
# Out:
# array([107., 106., 106., ..., 106., 105., 104.])

# %%
imagen_mat.shape = (imagen_gr.size[1], imagen_gr.size[0])
imagen_mat
# Out:
# array([[107., 106., 106., ..., 250., 250., 250.],
#        [106., 107., 109., ..., 250., 250., 250.],
#        [110., 111., 111., ..., 250., 250., 250.],
#        ...,
#        [ 45.,  46.,  44., ..., 105., 104., 104.],
#        [ 47.,  46.,  44., ..., 106., 104., 107.],
#        [ 47.,  48.,  48., ..., 106., 105., 104.]])

# %%
print(imagen_mat.shape)
# Out:
# (1414, 2121)

# %%
plt.imshow(imagen_mat, cmap='gray')
plt.show()

# %%
imagen_mat_2 = imagen_mat/10
imagen_mat_2
# Out:
# array([[10.7, 10.6, 10.6, ..., 25. , 25. , 25. ],
#        [10.6, 10.7, 10.9, ..., 25. , 25. , 25. ],
#        [11. , 11.1, 11.1, ..., 25. , 25. , 25. ],
#        ...,
#        [ 4.5,  4.6,  4.4, ..., 10.5, 10.4, 10.4],
#        [ 4.7,  4.6,  4.4, ..., 10.6, 10.4, 10.7],
#        [ 4.7,  4.8,  4.8, ..., 10.6, 10.5, 10.4]])

# %%
plt.imshow(imagen_mat_2)
plt.show()

# %%
plt.imshow(imagen_mat_2, cmap='gray')
plt.show()

# %%
print(np.max(imagen_mat_2))
print(np.max(imagen_mat))
# Out:
# 25.1
# 251.0

# %%
print(np.min(imagen_mat_2))
print(np.min(imagen_mat))
# Out:
# 0.4
# 4.0
